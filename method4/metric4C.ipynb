# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %% [markdown]
# ## Read CSV

# %%
df = pd.read_csv("allyear.csv")

# %%
df.drop(['county'],axis=1,inplace=True)
df.reset_index()
df
# Out:
#      population  unemployedRate  povertyRate  medianIncome  avgmealmon  \
# 0        263670           4.875        0.111         63389        3.43
# 1        932202           3.425        0.056        108827        4.00
# 2        445349           3.175        0.055         88797        3.49
# 3        506471           3.900        0.107         73672        3.58
# 4         92039           7.283        0.088         69980        3.71
# ..          ...             ...          ...           ...         ...
# 100       63732           7.258        0.114         68830        3.53
# 101      329626           4.508        0.052         98440        3.41
# 102      143004           5.367        0.048         85086        3.58
# 103      549905           5.975        0.106         71163        3.02
# 104      106742           5.292        0.072         71277        3.54
#
#      homeless  pplweekmon  drivealone  carpooled  publicTrans  walked  \
# ...

# %% [markdown]
# ## Variable Cutoff

# %%
# get all explanatory variable names
array = []
for col in df.columns:
    array.append(col)
del array[-1]

combos=[]
opvars = []

# unique combinations
x=0
for i in array[x:]:
    for j in array[x+1:]:
        column_1 = df[i]
        column_2 = df[j]
        combos.append((i,j))
    x=x+1
    
# variable cutoff
for i in combos:
    c1=df[i[0]]
    c2=df[i[1]]
    corr = abs(c1.corr(c2))
    if corr > 0.95:
        snapcol = df['POP_SNAP']
        corr_snap1 = abs(c1.corr(snapcol))
        corr_snap2 = abs(c2.corr(snapcol))
        if (corr_snap2>corr_snap1 and i[1] not in opvars):    # replacement function
            if (i[0] not in opvars):
                opvars.append(i[1])
            else:
                index = opvars.index(i[0])
                opvars[index] = i[1]
        elif (corr_snap1>corr_snap2 and i[0] not in opvars):
            if (i[1] not in opvars):
                opvars.append(i[0])
            else:
                index = opvars.index(i[1])
                opvars[index] = i[0]

print(opvars)
# Out:
# ['population', 'medianIncome', 'yeshealth', 'privatehealth']

# %%
# set new dataframe with optimized variables and response variable POP_SNAP
opvars.append('POP_SNAP')
df = df[opvars]
df
# Out:
#      population  medianIncome  yeshealth  privatehealth  POP_SNAP
# 0        263670         63389     238684         167592     32072
# 1        932202        108827     862372         706314     30301
# 2        445349         88797     407683         345164     19123
# 3        506471         73672     468706         344865     59120
# 4         92039         69980      83788          61367      6712
# ..          ...           ...        ...            ...       ...
# 100       63732         68830      59606          45104      9325
# 101      329626         98440     311777         274229     12874
# 102      143004         85086     136333         115072      4735
# 103      549905         71163     481160         361658     49795
# 104      106742         71277      99484          81728      7542
#
# [105 rows x 5 columns]

# %% [markdown]
# ## Multiple Linear Regression

# %%
x = df.drop(['POP_SNAP'],axis=1).values
y = df['POP_SNAP'].values

# %%
# splitting dataset into training and test set
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33, random_state=0)

# training model on training set
ml = LinearRegression()
ml.fit(x_train,y_train)

# predict test set results
y_pred=ml.predict(x_test)

plt.figure(figsize=(8,5))
plt.scatter(y_test,y_pred,color="red")
plt.xlabel('Actual', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel('Predicted', fontsize=16)
plt.title('Method 4C', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Method 4C')

# %%
# define our intput
X2 = sm.add_constant(x)

# create a OLS model
model = sm.OLS(y, X2)

# fit the data
est = model.fit()

print(est.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.932
# Method:                 Least Squares   F-statistic:                     359.8
# Date:                Sat, 31 Jul 2021   Prob (F-statistic):           2.06e-58
# Time:                        15:05:34   Log-Likelihood:                -1097.4
# No. Observations:                 105   AIC:                             2205.
# Df Residuals:                     100   BIC:                             2218.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.163e+04   5382.396      2.161      0.033     953.643    2.23e+04
# ...

# %%
plt.figure(figsize=(8,5))

plt.xlabel('Actual', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel('Predicted', fontsize=16)
plt.title('Metric 4C/2C', fontsize=16)

plt.scatter(y_test,y_pred,color="purple", label='adj. R squared: 0.932')

mC, bC = np.polyfit(y_test, y_pred, 1)

plt.plot(y_test, mC*y_test + bC, color='orange')

plt.legend(fontsize=15)
