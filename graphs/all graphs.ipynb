# %% [markdown]
# # Trial

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %% [markdown]
# ## Correlation testing + heatmaps

# %%
df = pd.read_csv("allyear.csv")

# %%
df.drop(['county'],axis=1,inplace=True)
df.reset_index()
df
# Out:
#      population  unemployedRate  povertyRate  medianIncome  avgmealmon  \
# 0        263670           4.875        0.111         63389        3.43
# 1        932202           3.425        0.056        108827        4.00
# 2        445349           3.175        0.055         88797        3.49
# 3        506471           3.900        0.107         73672        3.58
# 4         92039           7.283        0.088         69980        3.71
# ..          ...             ...          ...           ...         ...
# 100       63732           7.258        0.114         68830        3.53
# 101      329626           4.508        0.052         98440        3.41
# 102      143004           5.367        0.048         85086        3.58
# 103      549905           5.975        0.106         71163        3.02
# 104      106742           5.292        0.072         71277        3.54
#
#      homeless  pplweekmon  drivealone  carpooled  publicTrans  walked  \
# 0         357      62.840      100267       9897         4174    5923
# 1         271      45.530      323546      31853        82264   10764
# 2         518      39.550      185678      18855         6989    1733
# 3         603      58.000      188830      24875        15967    3665
# 4          90      72.600       32620       4167          232    2625
# ..        ...         ...         ...        ...          ...     ...
# 100        38      86.770       24202       2597          201     466
# 101       342      43.307      134577      12021         8140    3684
# 102        57      50.034       64944       4956         1040    1145
# 103       504      54.202      177773      22037        34254    8130
# 104        58      61.756       43581       3883         1077    2116
#
#      meanHouseIncome  yeshealth  privatehealth  publichealth  nohealth  \
# 0              93192     238684         167592        106540     22656
# 1             147611     862372         706314        247591     64289
# 2             114940     407683         345164        125525     19669
# 3             100804     468706         344865        186648     32088
# 4              98993      83788          61367         40763      6102
# ..               ...        ...            ...           ...       ...
# 100            88766      59606          45104         23619      3332
# 101           132892     311777         274229         71082     18776
# 102           109179     136333         115072         38680      6468
# 103           102929     481160         361658        165957     69732
# 104            89871      99484          81728         30788      6383
#
#      POP_SNAP
# 0       32072
# 1       30301
# 2       19123
# 3       59120
# 4        6712
# ..        ...
# 100      9325
# 101     12874
# 102      4735
# 103     49795
# 104      7542
#
# [105 rows x 17 columns]

# %%
corr = df.corr()
corr
# Out:
#                  population  unemployedRate  povertyRate  medianIncome  \
# population         1.000000       -0.263586     0.090570      0.084500
# unemployedRate    -0.263586        1.000000     0.500398     -0.681562
# povertyRate        0.090570        0.500398     1.000000     -0.848366
# medianIncome       0.084500       -0.681562    -0.848366      1.000000
# avgmealmon        -0.019133       -0.194684    -0.287375      0.332101
# homeless           0.591383       -0.025236     0.384512     -0.266453
# pplweekmon        -0.050700        0.662080     0.690082     -0.773294
# drivealone         0.945830       -0.317279    -0.112686      0.237963
# carpooled          0.942731       -0.263877     0.162925      0.041811
# publicTrans        0.674527       -0.138395     0.318465     -0.091909
# walked             0.686380       -0.087871     0.401652     -0.164310
# meanHouseIncome    0.224894       -0.670894    -0.749107      0.950289
# yeshealth          0.998130       -0.279376     0.047779      0.118544
# privatehealth      0.975020       -0.326512    -0.089406      0.237254
# publichealth       0.940448       -0.146743     0.310709     -0.157232
# nohealth           0.861809       -0.078733     0.415315     -0.193366
# POP_SNAP           0.660805        0.096361     0.674003     -0.475714
#
#                  avgmealmon  homeless  pplweekmon  drivealone  carpooled  \
# population        -0.019133  0.591383   -0.050700    0.945830   0.942731
# unemployedRate    -0.194684 -0.025236    0.662080   -0.317279  -0.263877
# povertyRate       -0.287375  0.384512    0.690082   -0.112686   0.162925
# medianIncome       0.332101 -0.266453   -0.773294    0.237963   0.041811
# avgmealmon         1.000000  0.108051    0.124277   -0.007948  -0.113825
# homeless           0.108051  1.000000    0.453408    0.449822   0.523188
# pplweekmon         0.124277  0.453408    1.000000   -0.201595  -0.085880
# drivealone        -0.007948  0.449822   -0.201595    1.000000   0.892804
# carpooled         -0.113825  0.523188   -0.085880    0.892804   1.000000
# publicTrans        0.026737  0.569306    0.165905    0.422139   0.613113
# walked            -0.060991  0.581056    0.190965    0.438373   0.664018
# meanHouseIncome    0.416164 -0.064108   -0.654971    0.335013   0.160592
# yeshealth         -0.017426  0.562882   -0.083486    0.959275   0.938223
# privatehealth     -0.002830  0.473726   -0.185484    0.976683   0.910184
# publichealth      -0.065868  0.670776    0.128149    0.844619   0.885444
# nohealth          -0.028130  0.684638    0.211323    0.684538   0.839203
# POP_SNAP          -0.138293  0.746321    0.443268    0.463006   0.674770
#
#                  publicTrans    walked  meanHouseIncome  yeshealth  \
# population          0.674527  0.686380         0.224894   0.998130
# unemployedRate     -0.138395 -0.087871        -0.670894  -0.279376
# povertyRate         0.318465  0.401652        -0.749107   0.047779
# medianIncome       -0.091909 -0.164310         0.950289   0.118544
# avgmealmon          0.026737 -0.060991         0.416164  -0.017426
# homeless            0.569306  0.581056        -0.064108   0.562882
# pplweekmon          0.165905  0.190965        -0.654971  -0.083486
# drivealone          0.422139  0.438373         0.335013   0.959275
# carpooled           0.613113  0.664018         0.160592   0.938223
# publicTrans         1.000000  0.947683         0.068612   0.645294
# walked              0.947683  1.000000         0.001881   0.654390
# meanHouseIncome     0.068612  0.001881         1.000000   0.250363
# yeshealth           0.645294  0.654390         0.250363   1.000000
# privatehealth       0.573866  0.570985         0.349031   0.985432
# publichealth        0.652674  0.692385        -0.006497   0.929147
# nohealth            0.831374  0.876404        -0.007616   0.830742
# POP_SNAP            0.679789  0.755258        -0.318795   0.623689
#
#                  privatehealth  publichealth  nohealth  POP_SNAP
# population            0.975020      0.940448  0.861809  0.660805
# unemployedRate       -0.326512     -0.146743 -0.078733  0.096361
# povertyRate          -0.089406      0.310709  0.415315  0.674003
# medianIncome          0.237254     -0.157232 -0.193366 -0.475714
# avgmealmon           -0.002830     -0.065868 -0.028130 -0.138293
# homeless              0.473726      0.670776  0.684638  0.746321
# pplweekmon           -0.185484      0.128149  0.211323  0.443268
# drivealone            0.976683      0.844619  0.684538  0.463006
# carpooled             0.910184      0.885444  0.839203  0.674770
# publicTrans           0.573866      0.652674  0.831374  0.679789
# walked                0.570985      0.692385  0.876404  0.755258
# meanHouseIncome       0.349031     -0.006497 -0.007616 -0.318795
# yeshealth             0.985432      0.929147  0.830742  0.623689
# privatehealth         1.000000      0.858666  0.743158  0.489266
# publichealth          0.858666      1.000000  0.878965  0.816768
# nohealth              0.743158      0.878965  1.000000  0.864358
# POP_SNAP              0.489266      0.816768  0.864358  1.000000

# %%
plt.figure(figsize=(12, 12))
# plot the correlation heatmap
#sns.heatmap(corr, vmin=-1, vmax=1, cmap='coolwarm')
sns.heatmap(corr, vmin=-1, vmax=1, cmap='RdBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # metric cutoff testing

# %%
array = ['population','unemployedRate','povertyRate','medianIncome','avgmealmon','homeless','pplweekmon','drivealone','carpooled','publicTrans','walked','meanHouseIncome','yeshealth','privatehealth','publichealth','nohealth']
combos=[]
opvars = []
removed = []

x=0
for i in array[x:]:
    for j in array[x+1:]:
        column_1 = df[i]
        column_2 = df[j]
        combos.append((i,j))
    x=x+1

for i in combos:
    c1=df[i[0]]
    c2=df[i[1]]
    corr = abs(c1.corr(c2))
    if corr > 0.95:
        snapcol = df['POP_SNAP']
        corr_snap1 = abs(c1.corr(snapcol))
        corr_snap2 = abs(c2.corr(snapcol))
        if (corr_snap2>corr_snap1 and i[1] not in opvars):
            if (i[0] not in opvars):
                opvars.append(i[1])
            else:
                index = opvars.index(i[0])
                opvars[index] = i[1]
        elif (corr_snap1>corr_snap2 and i[0] not in opvars):
            if (i[1] not in opvars):
                opvars.append(i[0])
            else:
                index = opvars.index(i[1])
                opvars[index] = i[0]

print(opvars)
# Out:
# ['population', 'medianIncome', 'yeshealth', 'privatehealth']

# %%
opvars = ['population', 'privatehealth', 'medianIncome', 'yeshealth']
opvars.append('POP_SNAP')

# %% [markdown]
# ## Developing metric using multiple linear regression

# %%
df = df[opvars]

# %%
df
# Out:
#      population  privatehealth  medianIncome  yeshealth  POP_SNAP
# 0        263670         167592         63389     238684     32072
# 1        932202         706314        108827     862372     30301
# 2        445349         345164         88797     407683     19123
# 3        506471         344865         73672     468706     59120
# 4         92039          61367         69980      83788      6712
# ..          ...            ...           ...        ...       ...
# 100       63732          45104         68830      59606      9325
# 101      329626         274229         98440     311777     12874
# 102      143004         115072         85086     136333      4735
# 103      549905         361658         71163     481160     49795
# 104      106742          81728         71277      99484      7542
#
# [105 rows x 5 columns]

# %% [markdown]
# ## training model

# %%
x = df.drop(['POP_SNAP'],axis=1).values
y = df['POP_SNAP'].values

# %%
# splitting dataset into training and test set
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3, random_state=0)

# %%
# training model on training set
ml = LinearRegression()
ml.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# predict test set results
y_pred=ml.predict(x_test)
print(y_pred)
# Out:
# [ 27459.63562452  64074.35811639  22155.60787739   8208.32617773
#   46055.65414244 113199.65662655   9227.95067198   8896.11767879
#   61790.84836083  51047.89298263  55361.02166441   8140.63823917
#    2142.21481583  12901.9185775   15065.34675507   2692.46224935
#   46894.89104889  57006.24368306  20713.83593995  97207.50303883
#   52818.00292852  32056.3979001   57290.46677182  40255.82331837
#   61647.09629222  27934.86998183 121260.02522064  21665.36415923
#   34958.42051139   9096.82573847  35817.08435664  62235.3956098 ]

# %%
# testing one value
#ml.predict([[106540,22656,5923]])

# %%
# scatterplot of results
plt.figure(figsize=(12,10))
plt.scatter(y_test,y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted')

# %%
# define our intput
X2 = sm.add_constant(x)

# create a OLS model
model = sm.OLS(y, X2)

# fit the data
est = model.fit()

print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.932
# Method:                 Least Squares   F-statistic:                     359.8
# Date:                Thu, 22 Jul 2021   Prob (F-statistic):           2.06e-58
# Time:                        21:28:17   Log-Likelihood:                -1097.4
# No. Observations:                 105   AIC:                             2205.
# Df Residuals:                     100   BIC:                             2218.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.163e+04   5382.396      2.161      0.033     953.643    2.23e+04
# x1             0.1360      0.095      1.431      0.155      -0.052       0.324
# x2            -0.6704      0.056    -11.973      0.000      -0.781      -0.559
# x3            -0.1119      0.067     -1.671      0.098      -0.245       0.021
# x4             0.4657      0.140      3.331      0.001       0.188       0.743
# ==============================================================================
# Omnibus:                        5.191   Durbin-Watson:                   2.052
# Prob(Omnibus):                  0.075   Jarque-Bera (JB):                4.689
# Skew:                          -0.402   Prob(JB):                       0.0959
# Kurtosis:                       3.652   Cond. No.                     4.89e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.89e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import pylab

# check for the normality of the residuals
sm.qqplot(est.resid, line='s')
pylab.show()

# also check that the mean of the residuals is approx. 0.
mean_residuals = sum(est.resid)/ len(est.resid)
print("The mean of the residuals is {:.4}".format(mean_residuals))
# Out:
# The mean of the residuals is 4.241e-11

# %% [markdown]
# ## testing 2020 values to predict SNAP data

# %%
df20 = pd.read_csv('mod4-2020.csv')
df20
# Out:
#         county  population  privatehealth  medianIncome  yeshealth  POP_SNAP  \
# 0     ATLANTIC      262945         171307         37802     281052     33493
# 1       BERGEN      930394         718702         52631     860045     31748
# 2   BURLINGTON      446596         349689         55674     413360     19921
# 3       CAMDEN      506809         347707         52960     469026     65111
# 4     CAPE MAY       91546          63816         50654      84443      7226
# 5   CUMBERLAND      147008          84805         47798     125890     24564
# 6        ESSEX      800501         486651         25148     701519    108978
# 7   GLOUCESTER      293245         231496         63171     279835     16514
# 8       HUDSON      671666         404398         12085     584415     96196
# 9    HUNTERDON      124797         103338         83300     117733      2713
# 10      MERCER      367239         269040         64529     336076     29588
# 11   MIDDLESEX      822736         630156         77043     762935     48846
# 12    MONMOUTH      618381         496245         56600     582662     27358
# 13      MORRIS      491087         407297         73144     466080     12358
# 14       OCEAN      614237         432124         45858     581265     45533
# 15     PASSAIC      500382         282445         10277     434836     89632
# 16       SALEM       62451          44560         58985      58012      7879
# 17    SOMERSET      329331         272905         65040     310509      9424
# 18      SUSSEX      140002         119077         54191     135665      3907
# 19       UNION      555394         370900         51849     489629     39948
# 20      WARREN      105624          82875         51945      99487      7088
#
#     snapPred20
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN

# %%
pred20=[]
for index, row in df20.iterrows():
    pred = int(ml.predict([[row['population'], row['privatehealth'], row['medianIncome'], row['yeshealth']]]))
    pred20.append(pred)
print(pred20)
# Out:
# [47045, 49983, 22988, 56891, 12894, 27328, 119542, 16747, 103452, 4450, 29872, 47203, 25157, 12187, 64807, 90595, 9032, 9200, 5310, 62658, 8809]

# %%
predequation = []
for index, row in df20.iterrows():
    equation = int(11630-4672+0.1360*row['population']-0.6704*row['privatehealth']-0.1119*row['medianIncome']+0.4657*row['yeshealth'])
    predequation.append(equation)
print(predequation)
# Out:
# [54530, 46307, 19535, 55280, 10282, 23376, 113458, 14894, 98005, 159, 25827, 43071, 23387, 9562, 66361, 87011, 5994, 6117, 3284, 56058, 6281]

# %%
snap20 =[]
for i in df20['POP_SNAP']:
    snap20.append(i)

# %%
errors=[]
j=0
while j<len(pred20):
    err = abs((pred20[j]-snap20[j])/snap20[j])
    errors.append(err)
    j=j+1
avgerr = sum(errors)/len(errors)
print(avgerr)
# Out:
# 0.2330903118763097

# %%
residuals = []
k=0
while k<len(pred20):
    residual = snap20[k]-pred20[k]
    residuals.append(residual)
    k=k+1
avgres = sum(residuals)/len(pred20)
print(avgres)
# Out:
# -4672.619047619048

# %%
df20['snapPred20'] = pred20
df20
# Out:
#         county  population  privatehealth  medianIncome  yeshealth  POP_SNAP  \
# 0     ATLANTIC      262945         171307         37802     281052     33493
# 1       BERGEN      930394         718702         52631     860045     31748
# 2   BURLINGTON      446596         349689         55674     413360     19921
# 3       CAMDEN      506809         347707         52960     469026     65111
# 4     CAPE MAY       91546          63816         50654      84443      7226
# 5   CUMBERLAND      147008          84805         47798     125890     24564
# 6        ESSEX      800501         486651         25148     701519    108978
# 7   GLOUCESTER      293245         231496         63171     279835     16514
# 8       HUDSON      671666         404398         12085     584415     96196
# 9    HUNTERDON      124797         103338         83300     117733      2713
# 10      MERCER      367239         269040         64529     336076     29588
# 11   MIDDLESEX      822736         630156         77043     762935     48846
# 12    MONMOUTH      618381         496245         56600     582662     27358
# 13      MORRIS      491087         407297         73144     466080     12358
# 14       OCEAN      614237         432124         45858     581265     45533
# 15     PASSAIC      500382         282445         10277     434836     89632
# 16       SALEM       62451          44560         58985      58012      7879
# 17    SOMERSET      329331         272905         65040     310509      9424
# 18      SUSSEX      140002         119077         54191     135665      3907
# 19       UNION      555394         370900         51849     489629     39948
# 20      WARREN      105624          82875         51945      99487      7088
#
#     snapPred20
# 0        47045
# 1        49983
# 2        22988
# 3        56891
# 4        12894
# 5        27328
# 6       119542
# 7        16747
# 8       103452
# 9         4450
# 10       29872
# 11       47203
# 12       25157
# 13       12187
# 14       64807
# 15       90595
# 16        9032
# 17        9200
# 18        5310
# 19       62658
# 20        8809

# %% [markdown]
# ## bar graph pred vs actual 2020 SNAP

# %%
# set width of bars
plt.figure(figsize=(70, 28))
barWidth = 0.27
 
#Set position of bar on X axis
r1 = np.arange(len(pred20))
r2 = [x + barWidth for x in r1]
 
# Make the plot
plt.bar(r1, pred20, color='#08366A', width=barWidth, edgecolor='white', label='prediction')
plt.bar(r2, snap20, color='#EA8E70', width=barWidth, edgecolor='white', label='actual')
 
# Add xticks on the middle of the group bars
plt.ylabel('number of snap recipients', fontweight='bold', fontsize=50)
plt.yticks(fontsize=40)
plt.xlabel('counties', fontweight='bold', fontsize=50)
plt.xticks([r + barWidth for r in range(len(pred20))], ['Atlantic', 'Bergen', 'Burlington','Camden','Cape May',
                                                       'Cumberland','Essex','Gloucester','Hudson','Hunterdon',
                                                       'Mercer','Middlesex','Monmouth','Morris','Ocean','Passaic',
                                                       'Salem','Somerset','Sussex','Union','Warren'], fontsize=20)
plt.xticks(fontsize=28)
# Create legend & Show graphic
plt.legend(fontsize=40)
plt.title('2020 SNAP predicted vs actual', fontsize=70)
plt.show()

# %% [markdown]
# ## testing 2021 data to predict SNAP data

# %%
df21 = pd.read_csv('mod4-2021.csv')
df21
# Out:
#         county  pop2021  privatehealth  medianIncome  yeshealth  POP_SNAP  \
# 0     ATLANTIC   263032         171382         50214     239926     39938
# 1       BERGEN   930974         718754         71549     860312     36545
# 2   BURLINGTON   446557         349673         68545     413314     22424
# 3       CAMDEN   506707         347373         59244     468879     73810
# 4     CAPE MAY    91225          63327         58461      84215      8207
# 5   CUMBERLAND   147311          84685         49631     125948     27583
# 6        ESSEX   799785         485632         36974     700450    128748
# 7   GLOUCESTER   291858         230123         71953     278030     17857
# 8       HUDSON   673311         405160         33000     585750    114779
# 9    HUNTERDON   123499         101488         94942     117707      3031
# 10      MERCER   365914         270455         69692     335437     34261
# 11   MIDDLESEX   822842         630161         80898     763002     54814
# 12    MONMOUTH   615467         495815         74366     580874     30849
# 13      MORRIS   489395         404398         88311     464768     13889
# 14       OCEAN   618602         436081         56612     586954     51542
# 15     PASSAIC   499112         281815         31724     433724     94100
# 16       SALEM    61663          44787         60591      57563      8450
# 17    SOMERSET   326440         270433         83512     307042     10563
# 18      SUSSEX   139862         119298         69435     135686      4154
# 19       UNION   556219         371747         61341     491020     48034
# 20      WARREN   104745          83587         62396      99252      8322
#
#     snapPred21
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN

# %%
pred21=[]
for index, row in df21.iterrows():
    pred = int(ml.predict([[row['pop2021'], row['privatehealth'], row['medianIncome'], row['yeshealth']]]))
    pred21.append(pred)
print(pred21)
# Out:
# [36483, 49085, 22217, 56665, 12588, 27406, 119008, 16228, 102580, 4518, 28096, 47023, 23027, 12279, 64413, 89061, 8435, 7930, 4232, 62157, 7405]

# %%
snap21 =[]
for i in df21['POP_SNAP']:
    snap21.append(i)

# %%
errors=[]
j=0
while j<len(pred21):
    err = abs((pred21[j]-snap21[j])/snap21[j])
    errors.append(err)
    j=j+1
avgerr = sum(errors)/len(errors)
print(avgerr)
# Out:
# 0.17352388871593402

# %%
df21['snapPred21'] = pred21
df21
# Out:
#         county  pop2021  privatehealth  medianIncome  yeshealth  POP_SNAP  \
# 0     ATLANTIC   263032         171382         50214     239926     39938
# 1       BERGEN   930974         718754         71549     860312     36545
# 2   BURLINGTON   446557         349673         68545     413314     22424
# 3       CAMDEN   506707         347373         59244     468879     73810
# 4     CAPE MAY    91225          63327         58461      84215      8207
# 5   CUMBERLAND   147311          84685         49631     125948     27583
# 6        ESSEX   799785         485632         36974     700450    128748
# 7   GLOUCESTER   291858         230123         71953     278030     17857
# 8       HUDSON   673311         405160         33000     585750    114779
# 9    HUNTERDON   123499         101488         94942     117707      3031
# 10      MERCER   365914         270455         69692     335437     34261
# 11   MIDDLESEX   822842         630161         80898     763002     54814
# 12    MONMOUTH   615467         495815         74366     580874     30849
# 13      MORRIS   489395         404398         88311     464768     13889
# 14       OCEAN   618602         436081         56612     586954     51542
# 15     PASSAIC   499112         281815         31724     433724     94100
# 16       SALEM    61663          44787         60591      57563      8450
# 17    SOMERSET   326440         270433         83512     307042     10563
# 18      SUSSEX   139862         119298         69435     135686      4154
# 19       UNION   556219         371747         61341     491020     48034
# 20      WARREN   104745          83587         62396      99252      8322
#
#     snapPred21
# 0        36483
# 1        49085
# 2        22217
# 3        56665
# 4        12588
# 5        27406
# 6       119008
# 7        16228
# 8       102580
# 9         4518
# 10       28096
# 11       47023
# 12       23027
# 13       12279
# 14       64413
# 15       89061
# 16        8435
# 17        7930
# 18        4232
# 19       62157
# 20        7405

# %%
pop21 =[]
for i in df21['pop2021']:
    pop21.append(i)

# %%
percent = []
for m in range(len(pop21)):
    percent.append((snap21[m]/pop21[m])*100)
    
df21['percent'] = percent
df21
# Out:
#         county  pop2021  privatehealth  medianIncome  yeshealth  POP_SNAP  \
# 0     ATLANTIC   263032         171382         50214     239926     39938
# 1       BERGEN   930974         718754         71549     860312     36545
# 2   BURLINGTON   446557         349673         68545     413314     22424
# 3       CAMDEN   506707         347373         59244     468879     73810
# 4     CAPE MAY    91225          63327         58461      84215      8207
# 5   CUMBERLAND   147311          84685         49631     125948     27583
# 6        ESSEX   799785         485632         36974     700450    128748
# 7   GLOUCESTER   291858         230123         71953     278030     17857
# 8       HUDSON   673311         405160         33000     585750    114779
# 9    HUNTERDON   123499         101488         94942     117707      3031
# 10      MERCER   365914         270455         69692     335437     34261
# 11   MIDDLESEX   822842         630161         80898     763002     54814
# 12    MONMOUTH   615467         495815         74366     580874     30849
# 13      MORRIS   489395         404398         88311     464768     13889
# 14       OCEAN   618602         436081         56612     586954     51542
# 15     PASSAIC   499112         281815         31724     433724     94100
# 16       SALEM    61663          44787         60591      57563      8450
# 17    SOMERSET   326440         270433         83512     307042     10563
# 18      SUSSEX   139862         119298         69435     135686      4154
# 19       UNION   556219         371747         61341     491020     48034
# 20      WARREN   104745          83587         62396      99252      8322
#
#     snapPred21    percent
# 0        36483  15.183704
# 1        49085   3.925459
# 2        22217   5.021531
# 3        56665  14.566604
# 4        12588   8.996437
# 5        27406  18.724332
# 6       119008  16.097826
# 7        16228   6.118386
# 8       102580  17.046952
# 9         4518   2.454271
# 10       28096   9.363129
# 11       47023   6.661546
# 12       23027   5.012291
# 13       12279   2.837994
# 14       64413   8.332013
# 15       89061  18.853484
# 16        8435  13.703518
# 17        7930   3.235817
# 18        4232   2.970070
# 19       62157   8.635807
# 20        7405   7.945009

# %% [markdown]
# # Cloropleth Map of 2021 data using GeoPandas and Matplotlib

# %%
# racial demographics per county
import geopandas as gpd
df21.head()
# Out:
#        county  pop2021  privatehealth  medianIncome  yeshealth  POP_SNAP  \
# 0    ATLANTIC   263032         171382         50214     239926     39938
# 1      BERGEN   930974         718754         71549     860312     36545
# 2  BURLINGTON   446557         349673         68545     413314     22424
# 3      CAMDEN   506707         347373         59244     468879     73810
# 4    CAPE MAY    91225          63327         58461      84215      8207
#
#    snapPred21    percent
# 0       36483  15.183704
# 1       49085   3.925459
# 2       22217   5.021531
# 3       56665  14.566604
# 4       12588   8.996437

# %%
file_path = 'County_Boundaries/County_Boundaries_of_NJ.shp'
map_df = gpd.read_file(file_path)
map_df.plot();

# %%
race = pd.read_csv('race19.csv')
race
# Out:
#         county  white  black  hisp-lat  asian nathaw-pacisl  natam  twoplus
# 0     ATLANTIC   56.0   17.1      19.4    8.1           0.1    0.7      2.7
# 1       BERGEN   55.1    7.4      21.0   17.0           0.1    0.5      2.2
# 2   BURLINGTON   66.6   18.3       8.5    5.4           0.1    0.3      3.0
# 3       CAMDEN   55.8   21.6      17.6    6.0           0.1    0.7      2.6
# 4     CAPE MAY   85.0    4.8       8.1    1.0           0.1    0.4      1.9
# 5   CUMBERLAND   45.4   21.9      31.8    1.4           0.2    1.6      3.1
# 6        ESSEX   30.2   41.9      23.8    5.9           0.1    0.8      2.4
# 7   GLOUCESTER   77.8   11.2       6.7    3.1           0.1    0.3      2.3
# 8       HUDSON   29.0   14.8      42.7   16.4           0.2    1.1      2.7
# 9    HUNTERDON   84.8    2.7       7.0    4.4           0.2    0.2      1.5
# 10      MERCER   48.2   21.5      18.5   11.9           0.2    0.6      2.5
# 11   MIDDLESEX   41.7   12.0      22.1   24.9           0.1    0.7      2.3
# 12    MONMOUTH   75.1    7.5      11.1    5.6           0.1    0.3      1.8
# 13      MORRIS   70.5    3.8      13.9   10.8           >0     0.3      1.9
# 14       OCEAN   84.3    3.6       9.5    1.9           >0     0.3      1.4
# 15     PASSAIC   40.3   14.9      42.9    5.7           0.2    1.5      2.8
# 16       SALEM   73.4   14.8       9.8    1.1            >0    0.6      2.4
# 17    SOMERSET   54.8   10.5      15.2   18.8           0.1    0.4      2.1
# 18      SUSSEX   85.1    2.7       9.2    2.0            >0    0.3      1.7
# 19       UNION   39.2   23.8      32.8    5.7           0.1    0.8      2.2
# 20      WARREN   80.4    5.7      10.2    2.9           0.1    0.4      1.7

# %%
merged = map_df.set_index('COUNTY').join(race.set_index('county'))
merged.head()
# Out:
#             OBJECTID         COUNTY_LAB   CO             GNIS_NAME    GNIS  \
# COUNTY
# ATLANTIC           1    Atlantic County  ATL    County of Atlantic  882270
# BERGEN             2      Bergen County  BER      County of Bergen  882271
# BURLINGTON         3  Burlington County  BUR  County of Burlington  882272
# CAMDEN             4      Camden County  CAM      County of Camden  882273
# CAPE MAY           5    Cape May County  CAP    County of Cape May  882274
#
#            FIPSSTCO FIPSCO          ACRES    SQ_MILES  POP2010  ...  \
# COUNTY                                                          ...
# ATLANTIC      34001      1  390815.404215  610.649069   274549  ...
# BERGEN        34003      3  153490.275182  239.828555   905116  ...
# BURLINGTON    34005      5  524903.339615  820.161468   448734  ...
# CAMDEN        34007      7  145598.488079  227.497638   513657  ...
# CAPE MAY      34009      9  183126.574240  286.135272    97265  ...
#
#                Shape_Leng    Shape_Area  \
# COUNTY
# ATLANTIC    650228.153906  1.702385e+10
# BERGEN      443326.122021  6.686010e+09
# BURLINGTON  788705.269533  2.286470e+10
# CAMDEN      494949.424444  6.342245e+09
# CAPE MAY    514564.858771  7.976962e+09
#
#                                                      geometry  white  black  \
# COUNTY
# ATLANTIC    POLYGON ((443056.010 311529.770, 443068.440 31...   56.0   17.1
# BERGEN      POLYGON ((656200.963 783614.366, 656141.127 78...   55.1    7.4
# BURLINGTON  POLYGON ((436626.690 491361.780, 436701.190 49...   66.6   18.3
# CAMDEN      POLYGON ((342763.990 423475.830, 342804.100 42...   55.8   21.6
# CAPE MAY    POLYGON ((390389.730 177065.130, 390410.170 17...   85.0    4.8
#
#             hisp-lat  asian nathaw-pacisl natam  twoplus
# COUNTY
# ATLANTIC        19.4    8.1           0.1   0.7      2.7
# BERGEN          21.0   17.0           0.1   0.5      2.2
# BURLINGTON       8.5    5.4           0.1   0.3      3.0
# CAMDEN          17.6    6.0           0.1   0.7      2.6
# CAPE MAY         8.1    1.0           0.1   0.4      1.9
#
# [5 rows x 29 columns]

# %%
merged['percent'] = percent
counties = ['Atlantic', 'Bergen', 'Burlington','Camden','Cape May','Cumberland','Essex','Gloucester','Hudson','Hunterdon','Mercer','Monmouth','Ocean','Passaic','Salem','Somerset','Sussex','Union','Warren','Morris','Middlesex']
merged['counties'] = counties
merged
# Out:
#             OBJECTID         COUNTY_LAB   CO             GNIS_NAME    GNIS  \
# COUNTY
# ATLANTIC           1    Atlantic County  ATL    County of Atlantic  882270
# BERGEN             2      Bergen County  BER      County of Bergen  882271
# BURLINGTON         3  Burlington County  BUR  County of Burlington  882272
# CAMDEN             4      Camden County  CAM      County of Camden  882273
# CAPE MAY           5    Cape May County  CAP    County of Cape May  882274
# CUMBERLAND         6  Cumberland County  CUM  County of Cumberland  882275
# ESSEX              7       Essex County  ESS       County of Essex  882276
# GLOUCESTER         8  Gloucester County  GLO  County of Gloucester  882277
# HUDSON             9      Hudson County  HUD      County of Hudson  882278
# HUNTERDON         10   Hunterdon County  HUN   County of Hunterdon  882228
# MERCER            11      Mercer County  MER      County of Mercer  882229
# MONMOUTH          12    Monmouth County  MON    County of Monmouth  882910
# OCEAN             13       Ocean County  OCE       County of Ocean  882279
# PASSAIC           14     Passaic County  PAS     County of Passaic  882232
# SALEM             15       Salem County  SAL       County of Salem  882233
# SOMERSET          16    Somerset County  SOM    County of Somerset  882234
# SUSSEX            17      Sussex County  SUS      County of Sussex  882236
# UNION             18       Union County  UNI       County of Union  882235
# WARREN            19      Warren County  WAR      County of Warren  882237
# MORRIS            20      Morris County  MOR      County of Morris  882231
# MIDDLESEX         21   Middlesex County  MID   County of Middlesex  882230
#
#            FIPSSTCO FIPSCO          ACRES    SQ_MILES  POP2010  ...  \
# COUNTY                                                          ...
# ATLANTIC      34001      1  390815.404215  610.649069   274549  ...
# BERGEN        34003      3  153490.275182  239.828555   905116  ...
# BURLINGTON    34005      5  524903.339615  820.161468   448734  ...
# CAMDEN        34007      7  145598.488079  227.497638   513657  ...
# CAPE MAY      34009      9  183126.574240  286.135272    97265  ...
# CUMBERLAND    34011     11  321150.321572  501.797378   156898  ...
# ESSEX         34013     13   83034.859489  129.741968   783969  ...
# GLOUCESTER    34015     15  215073.163717  336.051818   288288  ...
# HUDSON        34017     17   32982.400795   51.535001   634266  ...
# HUNTERDON     34019     19  279879.338602  437.311467   128349  ...
# MERCER        34021     21  146442.339373  228.816155   366513  ...
# MONMOUTH      34025     25  310834.264880  485.678539   630380  ...
# OCEAN         34029     29  485078.440831  757.935064   576567  ...
# PASSAIC       34031     31  126926.846048  198.323197   501226  ...
# SALEM         34033     33  222158.656047  347.122900    66083  ...
# SOMERSET      34035     35  195127.363184  304.886505   323444  ...
# SUSSEX        34037     37  342700.651525  535.469768   149265  ...
# UNION         34039     39   67438.592595  105.372801   536499  ...
# WARREN        34041     41  232042.967234  362.567136   108692  ...
# MORRIS        34027     27  308084.429539  481.381921   492276  ...
# MIDDLESEX     34023     23  202859.561531  316.968065   809858  ...
#
#                                                      geometry  white  black  \
# COUNTY
# ATLANTIC    POLYGON ((443056.010 311529.770, 443068.440 31...   56.0   17.1
# BERGEN      POLYGON ((656200.963 783614.366, 656141.127 78...   55.1    7.4
# BURLINGTON  POLYGON ((436626.690 491361.780, 436701.190 49...   66.6   18.3
# CAMDEN      POLYGON ((342763.990 423475.830, 342804.100 42...   55.8   21.6
# CAPE MAY    POLYGON ((390389.730 177065.130, 390410.170 17...   85.0    4.8
# CUMBERLAND  POLYGON ((333743.882 268331.623, 341456.371 26...   45.4   21.9
# ESSEX       POLYGON ((541167.940 755990.810, 541175.500 75...   30.2   41.9
# GLOUCESTER  POLYGON ((315738.780 382812.540, 315792.600 38...   77.8   11.2
# HUDSON      MULTIPOLYGON (((586210.281 660143.720, 586222....   29.0   14.8
# HUNTERDON   POLYGON ((391770.815 705704.676, 392388.938 70...   84.8    2.7
# MERCER      POLYGON ((430243.040 561670.400, 430241.770 56...   48.2   21.5
# MONMOUTH    MULTIPOLYGON (((633923.765 579357.834, 633936....   75.1    7.5
# OCEAN       POLYGON ((558823.650 485784.590, 558844.950 48...   84.3    3.6
# PASSAIC     POLYGON ((571665.371 838036.808, 564405.500 82...   40.3   14.9
# SALEM       POLYGON ((237257.740 347915.180, 237283.770 34...   73.4   14.8
# SOMERSET    POLYGON ((477019.000 700585.500, 477035.030 70...   54.8   10.5
# SUSSEX      POLYGON ((445227.700 915430.620, 449738.410 91...   85.1    2.7
# UNION       POLYGON ((532362.499 692149.483, 532524.353 69...   39.2   23.8
# WARREN      POLYGON ((370994.194 814703.856, 374212.172 81...   80.4    5.7
# MORRIS      POLYGON ((491990.770 820527.420, 492000.420 82...   70.5    3.8
# MIDDLESEX   POLYGON ((548930.697 641772.802, 550167.286 64...   41.7   12.0
#
#             hisp-lat  asian  nathaw-pacisl  natam twoplus    percent  \
# COUNTY
# ATLANTIC        19.4    8.1            0.1    0.7     2.7  15.183704
# BERGEN          21.0   17.0            0.1    0.5     2.2   3.925459
# BURLINGTON       8.5    5.4            0.1    0.3     3.0   5.021531
# CAMDEN          17.6    6.0            0.1    0.7     2.6  14.566604
# CAPE MAY         8.1    1.0            0.1    0.4     1.9   8.996437
# CUMBERLAND      31.8    1.4            0.2    1.6     3.1  18.724332
# ESSEX           23.8    5.9            0.1    0.8     2.4  16.097826
# GLOUCESTER       6.7    3.1            0.1    0.3     2.3   6.118386
# HUDSON          42.7   16.4            0.2    1.1     2.7  17.046952
# HUNTERDON        7.0    4.4            0.2    0.2     1.5   2.454271
# MERCER          18.5   11.9            0.2    0.6     2.5   9.363129
# MONMOUTH        11.1    5.6            0.1    0.3     1.8   6.661546
# OCEAN            9.5    1.9            >0     0.3     1.4   5.012291
# PASSAIC         42.9    5.7            0.2    1.5     2.8   2.837994
# SALEM            9.8    1.1             >0    0.6     2.4   8.332013
# SOMERSET        15.2   18.8            0.1    0.4     2.1  18.853484
# SUSSEX           9.2    2.0             >0    0.3     1.7  13.703518
# UNION           32.8    5.7            0.1    0.8     2.2   3.235817
# WARREN          10.2    2.9            0.1    0.4     1.7   2.970070
# MORRIS          13.9   10.8            >0     0.3     1.9   8.635807
# MIDDLESEX       22.1   24.9            0.1    0.7     2.3   7.945009
#
#               counties
# COUNTY
# ATLANTIC      Atlantic
# BERGEN          Bergen
# BURLINGTON  Burlington
# CAMDEN          Camden
# CAPE MAY      Cape May
# CUMBERLAND  Cumberland
# ESSEX            Essex
# GLOUCESTER  Gloucester
# HUDSON          Hudson
# HUNTERDON    Hunterdon
# MERCER          Mercer
# MONMOUTH      Monmouth
# OCEAN            Ocean
# PASSAIC        Passaic
# SALEM            Salem
# SOMERSET      Somerset
# SUSSEX          Sussex
# UNION            Union
# WARREN          Warren
# MORRIS          Morris
# MIDDLESEX    Middlesex
#
# [21 rows x 31 columns]

# %%
merged['percent']
# Out:
# COUNTY
# ATLANTIC      15.183704
# BERGEN         3.925459
# BURLINGTON     5.021531
# CAMDEN        14.566604
# CAPE MAY       8.996437
# CUMBERLAND    18.724332
# ESSEX         16.097826
# GLOUCESTER     6.118386
# HUDSON        17.046952
# HUNTERDON      2.454271
# MERCER         9.363129
# MONMOUTH       6.661546
# OCEAN          5.012291
# PASSAIC        2.837994
# SALEM          8.332013
# SOMERSET      18.853484
# SUSSEX        13.703518
# UNION          3.235817
# WARREN         2.970070
# MORRIS         8.635807
# MIDDLESEX      7.945009
# Name: percent, dtype: float64

# %%
merged['coords'] = merged['geometry'].apply(lambda x: x.centroid.coords[:])
merged['coords'] = [coords[0] for coords in merged['coords']]

# %%
# selects variable/feature of the map
feature = 'percent'

# minimal and maximal values of linear colormap
vmin, vmax = 0, 20


fig, ax = plt.subplots(1, figsize=(30, 25))

# plot map with the feature, indicate customizables
merged.plot(column=feature, cmap='Blues', linewidth=1.0, ax=ax, edgecolor='0.5')
ax.set_title('2021 Percent Distribution of Food Insecurity', fontsize=20)
ax.axis('off')

# data normalization before returning RGBA colors from the given colormap
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
#sm._A = []
cbar = fig.colorbar(sm);


#subset = merged[[merged.index['CUMBERLAND'] , merged.index['HUDSON'], merged.index['SOMERSET']]]
#merged.drop(merged.drop([merged.index['CUMBERLAND'] , merged.index['HUDSON'], merged.index['SOMERSET']]))

for _, row in merged.iterrows():
    plt.text(s=(row['counties']), x = row['coords'][0], y = row['coords'][1],
           horizontalalignment='center', fontdict = {'size': 12, 'weight':'bold'}, color='black')

for _, row in subset.iterrows():
    plt.text(s=(row['counties']), x = row['coords'][0], y = row['coords'][1],
           horizontalalignment='center', fontdict = {'size': 12, 'weight':'bold'}, color='white')

# %% [markdown]
# # line graph of 2015-2021 Bergen, Camden, Essex, Sussex county

# %%
# sample df
bergen = pd.read_csv('bergen.csv')
bergen
# Out:
#    year  RateUnemployed  population  privatehealth  medianIncome  yeshealth  \
# 0  2015           5.700      926391         717188         89023     853892
# 1  2016           4.942      928120         728957         93683     864092
# 2  2017           4.508      948406         722499         94107     868179
# 3  2018           3.992      932816         719986        100361     859058
# 4  2019           3.425      932202         706314        108827     862372
# 5  2020           9.842      930394         718702         52631     860045
# 6  2021           7.580      930974         718754         71549     860312
#
#    POP_SNAP
# 0     40208
# 1     39891
# 2     36628
# 3     33014
# 4     30301
# 5     49983
# 6     49085

# %%
# reading csv files and specifying variables
bg=pd.DataFrame({'year': bergen['year'], 'snap': bergen['POP_SNAP']})

camden = pd.read_csv('camden.csv')
cm=pd.DataFrame({'year': camden['year'], 'snap': camden['POP_SNAP']})

essex = pd.read_csv('essex.csv')
ex=pd.DataFrame({'year': essex['year'], 'snap': essex['POP_SNAP']})

sussex = pd.read_csv('sussex.csv')
sx=pd.DataFrame({'year': sussex['year'], 'snap': sussex['POP_SNAP']})

# initialize a figure
plt.figure(figsize=(15, 15))
 
# do a 2x2 chart
plt.subplot(221)
plt.plot('year', 'snap', data=bg[bg['year'] <= 2020], marker='o', color='orange',linewidth=2, label='actual')
plt.plot('year', 'snap', data=bg[bg['year'] >= 2020], marker='o', color='blue', linewidth=2, linestyle = '--', label='prediction')
plt.title('Bergen', fontsize=15, loc='left', style='italic')


plt.subplot(222)
plt.plot('year', 'snap', data=cm[cm['year'] <= 2020], marker='o', color='orange',linewidth=2, label='actual')
plt.plot('year', 'snap', data=cm[cm['year'] >= 2020], marker='o', color='blue', linewidth=2, linestyle = '--', label='prediction')
plt.title('Camden', fontsize=15, loc='left', style='italic')
plt.legend(fontsize=15)

plt.subplot(223)
plt.plot('year', 'snap', data=ex[ex['year'] <= 2020], marker='o', color='orange',linewidth=2, label='actual')
plt.plot('year', 'snap', data=ex[ex['year'] >= 2020], marker='o', color='blue', linewidth=2, linestyle = '--', label='prediction')
plt.title('Essex', fontsize=15, loc='left', style='italic')


plt.subplot(224)
plt.plot('year', 'snap', data=sx[sx['year'] <= 2020], marker='o', color='orange',linewidth=2, label='actual')
plt.plot('year', 'snap', data=sx[sx['year'] >= 2020], marker='o', color='blue', linewidth=2, linestyle = '--', label='prediction')
plt.title('Sussex', fontsize=15, loc='left', style='italic')


# adding a title:
plt.title('Counties')

# showing the graph
plt.show()

# %% [markdown]
# # plotting race distributions in NJ

# %%
race = pd.read_csv('race2.csv')
race
cm = sns.light_palette('teal', as_cmap=True)

corace = race.style.background_gradient(cmap=cm, low=0, high=1, axis=0)
corace
# Out:
# <style  type="text/css" >
# #T_f2eba_row0_col1,#T_f2eba_row3_col1,#T_f2eba_row3_col2,#T_f2eba_row10_col2{
#             background-color:  #b1d7d7;
#             color:  #000000;
#         }#T_f2eba_row0_col2{
#             background-color:  #bddede;
#             color:  #000000;
#         }#T_f2eba_row0_col3{
#             background-color:  #c0dfdf;
#             color:  #000000;
#         }#T_f2eba_row0_col4,#T_f2eba_row3_col3,#T_f2eba_row4_col7,#T_f2eba_row5_col1,#T_f2eba_row13_col7{
#             background-color:  #c6e2e2;
#             color:  #000000;
#         }#T_f2eba_row0_col6,#T_f2eba_row3_col6,#T_f2eba_row11_col6{
#             background-color:  #bfdfdf;
#             color:  #000000;
#         }#T_f2eba_row0_col7,#T_f2eba_row8_col7{
#             background-color:  #90c7c7;
#             color:  #000000;
#         }#T_f2eba_row1_col1,#T_f2eba_row1_col7,#T_f2eba_row6_col3,#T_f2eba_row19_col7{
#             background-color:  #b2d8d8;
#             color:  #000000;
#         }#T_f2eba_row1_col2,#T_f2eba_row12_col2,#T_f2eba_row12_col3{
#             background-color:  #dbecec;
#             color:  #000000;
#         }#T_f2eba_row1_col3,#T_f2eba_row2_col2{
#             background-color:  #bbdcdc;
#             color:  #000000;
#         }#T_f2eba_row1_col4,#T_f2eba_row2_col1{
#             background-color:  #9bcdcd;
#             color:  #000000;
#         }#T_f2eba_row1_col6,#T_f2eba_row3_col4,#T_f2eba_row6_col4,#T_f2eba_row7_col2{
#             background-color:  #d0e7e7;
#             color:  #000000;
#         }#T_f2eba_row2_col3,#T_f2eba_row4_col2{
#             background-color:  #e3f0f0;
#             color:  #000000;
#         }#T_f2eba_row2_col4,#T_f2eba_row19_col1{
#             background-color:  #d3e8e8;
#             color:  #000000;
#         }#T_f2eba_row2_col6,#T_f2eba_row7_col6,#T_f2eba_row12_col6,#T_f2eba_row13_col6,#T_f2eba_row14_col3,#T_f2eba_row14_col6,#T_f2eba_row18_col6,#T_f2eba_row20_col2{
#             background-color:  #e0efef;
#             color:  #000000;
#         }#T_f2eba_row2_col7{
#             background-color:  #7bbdbd;
#             color:  #000000;
#         }#T_f2eba_row3_col7{
#             background-color:  #96caca;
#             color:  #000000;
#         }#T_f2eba_row4_col1,#T_f2eba_row5_col7,#T_f2eba_row8_col3,#T_f2eba_row9_col1,#T_f2eba_row14_col1{
#             background-color:  #75baba;
#             color:  #000000;
#         }#T_f2eba_row4_col3,#T_f2eba_row13_col2,#T_f2eba_row14_col4{
#             background-color:  #e5f1f1;
#             color:  #000000;
#         }#T_f2eba_row4_col4,#T_f2eba_row7_col3,#T_f2eba_row8_col1,#T_f2eba_row9_col2,#T_f2eba_row9_col6,#T_f2eba_row14_col7,#T_f2eba_row16_col4,#T_f2eba_row18_col2{
#             background-color:  #e8f3f3;
#             color:  #000000;
#         }#T_f2eba_row4_col6,#T_f2eba_row9_col4,#T_f2eba_row17_col6,#T_f2eba_row20_col6{
#             background-color:  #d8ebeb;
#             color:  #000000;
#         }#T_f2eba_row5_col2{
#             background-color:  #b0d7d7;
#             color:  #000000;
#         }#T_f2eba_row5_col3{
#             background-color:  #98cbcb;
#             color:  #000000;
#         }#T_f2eba_row5_col4,#T_f2eba_row6_col1,#T_f2eba_row14_col2{
#             background-color:  #e6f2f2;
#             color:  #000000;
#         }#T_f2eba_row5_col6,#T_f2eba_row6_col2,#T_f2eba_row11_col4,#T_f2eba_row15_col3,#T_f2eba_row18_col1{
#             background-color:  #74b9b9;
#             color:  #000000;
#         }#T_f2eba_row6_col6,#T_f2eba_row11_col3,#T_f2eba_row19_col6{
#             background-color:  #b7dada;
#             color:  #000000;
#         }#T_f2eba_row6_col7,#T_f2eba_row16_col7{
#             background-color:  #a4d1d1;
#             color:  #000000;
#         }#T_f2eba_row7_col1{
#             background-color:  #83c1c1;
#             color:  #000000;
#         }#T_f2eba_row7_col4{
#             background-color:  #deeeee;
#             color:  #000000;
#         }#T_f2eba_row7_col7,#T_f2eba_row11_col7{
#             background-color:  #abd5d5;
#             color:  #000000;
#         }#T_f2eba_row8_col2,#T_f2eba_row15_col2,#T_f2eba_row16_col2{
#             background-color:  #c5e1e1;
#             color:  #000000;
#         }#T_f2eba_row8_col4,#T_f2eba_row8_col6,#T_f2eba_row10_col7{
#             background-color:  #9ecece;
#             color:  #000000;
#         }#T_f2eba_row9_col3{
#             background-color:  #e7f2f2;
#             color:  #000000;
#         }#T_f2eba_row9_col7{
#             background-color:  #e2f0f0;
#             color:  #000000;
#         }#T_f2eba_row10_col1{
#             background-color:  #c1dfdf;
#             color:  #000000;
#         }#T_f2eba_row10_col3{
#             background-color:  #c3e0e0;
#             color:  #000000;
#         }#T_f2eba_row10_col4,#T_f2eba_row17_col1{
#             background-color:  #b3d9d9;
#             color:  #000000;
#         }#T_f2eba_row10_col6,#T_f2eba_row16_col6{
#             background-color:  #c7e3e3;
#             color:  #000000;
#         }#T_f2eba_row11_col1{
#             background-color:  #cfe6e6;
#             color:  #000000;
#         }#T_f2eba_row11_col2,#T_f2eba_row12_col7,#T_f2eba_row17_col3{
#             background-color:  #cde5e5;
#             color:  #000000;
#         }#T_f2eba_row12_col1,#T_f2eba_row15_col7{
#             background-color:  #89c4c4;
#             color:  #000000;
#         }#T_f2eba_row12_col4{
#             background-color:  #d2e8e8;
#             color:  #000000;
#         }#T_f2eba_row13_col1{
#             background-color:  #93c8c8;
#             color:  #000000;
#         }#T_f2eba_row13_col3,#T_f2eba_row15_col1,#T_f2eba_row15_col4,#T_f2eba_row17_col2,#T_f2eba_row19_col4{
#             background-color:  #d1e8e8;
#             color:  #000000;
#         }#T_f2eba_row13_col4,#T_f2eba_row17_col7{
#             background-color:  #b9dbdb;
#             color:  #000000;
#         }#T_f2eba_row15_col6{
#             background-color:  #7dbebe;
#             color:  #000000;
#         }#T_f2eba_row16_col1{
#             background-color:  #8cc5c5;
#             color:  #000000;
#         }#T_f2eba_row16_col3,#T_f2eba_row20_col4{
#             background-color:  #dfeeee;
#             color:  #000000;
#         }#T_f2eba_row17_col4{
#             background-color:  #92c8c8;
#             color:  #000000;
#         }#T_f2eba_row18_col3{
#             background-color:  #e1efef;
#             color:  #000000;
#         }#T_f2eba_row18_col4{
#             background-color:  #e4f1f1;
#             color:  #000000;
#         }#T_f2eba_row18_col7,#T_f2eba_row20_col7{
#             background-color:  #d4e9e9;
#             color:  #000000;
#         }#T_f2eba_row19_col2{
#             background-color:  #aad4d4;
#             color:  #000000;
#         }#T_f2eba_row19_col3{
#             background-color:  #94c9c9;
#             color:  #000000;
#         }#T_f2eba_row20_col1{
#             background-color:  #7ebebe;
#             color:  #000000;
#         }#T_f2eba_row20_col3{
#             background-color:  #ddeded;
#             color:  #000000;
#         }</style><table id="T_f2eba_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >county</th>        <th class="col_heading level0 col1" >white</th>        <th class="col_heading level0 col2" >black</th>        <th class="col_heading level0 col3" >hisp-lat</th>        <th class="col_heading level0 col4" >asian</th>        <th class="col_heading level0 col5" >nathaw-pacisl</th>        <th class="col_heading level0 col6" >natam</th>        <th class="col_heading level0 col7" >twoplus</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f2eba_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f2eba_row0_col0" class="data row0 col0" >Atlantic</td>
#                         <td id="T_f2eba_row0_col1" class="data row0 col1" >56.000000</td>
#                         <td id="T_f2eba_row0_col2" class="data row0 col2" >17.100000</td>
#                         <td id="T_f2eba_row0_col3" class="data row0 col3" >19.400000</td>
#                         <td id="T_f2eba_row0_col4" class="data row0 col4" >8.100000</td>
#                         <td id="T_f2eba_row0

# %%
race['perSNAP']=percent

# %%
race
# Out:
#         county  white  black  hisp-lat  asian nathaw-pacisl  natam  twoplus  \
# 0     Atlantic   56.0   17.1      19.4    8.1           0.1    0.7      2.7
# 1       Bergen   55.1    7.4      21.0   17.0           0.1    0.5      2.2
# 2   Burlington   66.6   18.3       8.5    5.4           0.1    0.3      3.0
# 3       Camden   55.8   21.6      17.6    6.0           0.1    0.7      2.6
# 4     Cape May   85.0    4.8       8.1    1.0           0.1    0.4      1.9
# 5   Cumberland   45.4   21.9      31.8    1.4           0.2    1.6      3.1
# 6        Essex   30.2   41.9      23.8    5.9           0.1    0.8      2.4
# 7   Gloucester   77.8   11.2       6.7    3.1           0.1    0.3      2.3
# 8       Hudson   29.0   14.8      42.7   16.4           0.2    1.1      2.7
# 9    Hunterdon   84.8    2.7       7.0    4.4           0.2    0.2      1.5
# 10      Mercer   48.2   21.5      18.5   11.9           0.2    0.6      2.5
# 11   Middlesex   41.7   12.0      22.1   24.9           0.1    0.7      2.3
# 12    Monmouth   75.1    7.5      11.1    5.6           0.1    0.3      1.8
# 13      Morris   70.5    3.8      13.9   10.8           >0     0.3      1.9
# 14       Ocean   84.3    3.6       9.5    1.9           >0     0.3      1.4
# 15     Passaic   40.3   14.9      42.9    5.7           0.2    1.5      2.8
# 16       Salem   73.4   14.8       9.8    1.1            >0    0.6      2.4
# 17    Somerset   54.8   10.5      15.2   18.8           0.1    0.4      2.1
# 18      Sussex   85.1    2.7       9.2    2.0            >0    0.3      1.7
# 19       Union   39.2   23.8      32.8    5.7           0.1    0.8      2.2
# 20      Warren   80.4    5.7      10.2    2.9           0.1    0.4      1.7
#
#       perSNAP
# 0   15.183704
# 1    3.925459
# 2    5.021531
# 3   14.566604
# 4    8.996437
# 5   18.724332
# 6   16.097826
# 7    6.118386
# 8   17.046952
# 9    2.454271
# 10   9.363129
# 11   6.661546
# 12   5.012291
# 13   2.837994
# 14   8.332013
# 15  18.853484
# 16  13.703518
# 17   3.235817
# 18   2.970070
# 19   8.635807
# 20   7.945009

# %%
racecorr = race.corr()
racecorr
# Out:
#              white     black  hisp-lat     asian     natam   twoplus   perSNAP
# white     1.000000 -0.738863 -0.864720 -0.524457 -0.736567 -0.673734 -0.588510
# black    -0.738863  1.000000  0.465133  0.010357  0.517532  0.647205  0.618468
# hisp-lat -0.864720  0.465133  1.000000  0.322995  0.880990  0.575001  0.672135
# asian    -0.524457  0.010357  0.322995  1.000000  0.054191  0.142867 -0.180991
# natam    -0.736567  0.517532  0.880990  0.054191  1.000000  0.703523  0.845616
# twoplus  -0.673734  0.647205  0.575001  0.142867  0.703523  1.000000  0.658671
# perSNAP  -0.588510  0.618468  0.672135 -0.180991  0.845616  0.658671  1.000000

# %%
plt.figure(figsize=(9, 8))
sns.heatmap(racecorr, vmin=-1, vmax=1, cmap='RdBu', annot=True)
# Out:
# <AxesSubplot:>
